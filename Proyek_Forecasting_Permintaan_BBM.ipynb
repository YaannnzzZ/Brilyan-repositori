# %% [markdown]
# <a href="https://colab.research.google.com/github/YaannnzzZ/Brilyan-repositori/blob/main/Proyek_Forecasting_Permintaan_BBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================
# 📦 1. IMPORT LIBRARY
# ======================================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.statespace.sarimax import SARIMAX
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# ======================================
# 📂 2. LOAD & CEK DATA
# ======================================
df = pd.read_csv('/content/drive/MyDrive/Proyek Data Mining/Project Kecil/Data_Penjualan_dan_Pajak_BBM_di_DKI_Jakarta.csv')  # Ganti path sesuai file kamu
print(df.head())
print(df.info())
# Out:
#    bulan stasiun_pengisian_bahanbakar jenis_bahanbakar  jumlah_penjualan  \
# 0      8                    Pertamina        Pertalite          33509222
# 1      8                    Pertamina         Pertamax          52850550
# 2      8                    Pertamina    Pertamax Plus           2413000
# 3      8                    Pertamina    Pertamina Dex           2468000
# 4      8                    Pertamina          Dexlite           1094000
#
#    penerimaan_pajak  periode_data
# 0       10052766600          2016
# 1       16888563417          2016
# 2         865532573          2016
# 3         873780207          2016
# 4         306795657          2016
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bulan                         360 non-null    int64
#  1   stasiun_pengisian_bahanbakar  360 non-null    object
#  2   jenis_bahanbakar              360 non-null    object
#  3   jumlah_penjualan              360 non-null    int64
#  4   penerimaan_pajak              360 non-null    int64
#  5   periode_data                  360 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 17.0+ KB
# None

# %%
print(df.head(10))
# Out:
#    bulan stasiun_pengisian_bahanbakar jenis_bahanbakar  jumlah_penjualan  \
# 0      8                    Pertamina        Pertalite          33509222
# 1      8                    Pertamina         Pertamax          52850550
# 2      8                    Pertamina    Pertamax Plus           2413000
# 3      8                    Pertamina    Pertamina Dex           2468000
# 4      8                    Pertamina          Dexlite           1094000
# 5      8                    Pertamina  Pertamax Racing             16000
# 6      8                    Pertamina              BBG             50246
# 7      8                    Pertamina   Pertamax Turbo           1508000
# 8      8                        Total   Performance 92           1354611
# 9      8                        Total   Performance 95            224000
#
#    penerimaan_pajak  periode_data
# 0       10052766600          2016
# 1       16888563417          2016
# 2         865532573          2016
# 3         873780207          2016
# 4         306795657          2016
# 5          25739130          2016
# 6         429014716          2016
# 7         570417398          2016
# 8         441755444          2016
# 9          97773496          2016

# %%
print(df.isnull().sum())
# Out:
# bulan                           0
# stasiun_pengisian_bahanbakar    0
# jenis_bahanbakar                0
# jumlah_penjualan                0
# penerimaan_pajak                0
# periode_data                    0
# dtype: int64

# %%
df.rename(columns={'periode_data': 'Tahun'}, inplace=True)
df.rename(columns={'stasiun_pengisian_bahanbakar': 'Lokasi'}, inplace=True)

# %%
print(df.head())
# Out:
#    bulan     Lokasi jenis_bahanbakar  jumlah_penjualan  penerimaan_pajak  \
# 0      8  Pertamina        Pertalite          33509222       10052766600
# 1      8  Pertamina         Pertamax          52850550       16888563417
# 2      8  Pertamina    Pertamax Plus           2413000         865532573
# 3      8  Pertamina    Pertamina Dex           2468000         873780207
# 4      8  Pertamina          Dexlite           1094000         306795657
#
#    Tahun
# 0   2016
# 1   2016
# 2   2016
# 3   2016
# 4   2016

# %%
# ======================================
# 🔍 3. EDA (EXPLORATORY DATA ANALYSIS)
# ======================================
# Cek tren konsumsi BBM secara umum
df['tanggal'] = pd.to_datetime(df['Tahun'].astype(str) + '-' + df['bulan'].astype(str) + '-01')
df.sort_values('tanggal', inplace=True)

plt.figure(figsize=(12, 5))
sns.lineplot(data=df, x='tanggal', y='jumlah_penjualan', hue='jenis_bahanbakar')
plt.title('Tren Konsumsi BBM per Jenis')
plt.xlabel('Tanggal')
plt.ylabel('Volume (Liter)')
plt.show()

# %%
# ======================================
# 🧼 4. DATA PREPROCESSING
# ======================================
df['tanggal'] = pd.to_datetime(df['Tahun'].astype(str) + '-' + df['bulan'].astype(str) + '-01')
df.sort_values('tanggal', inplace=True)

# Filter Pertalite saja
df_plt = df[df['jenis_bahanbakar'].str.lower() == 'pertalite']
data = df_plt[['tanggal', 'jumlah_penjualan']].set_index('tanggal').asfreq('MS')

# %%
# 5.Visualisasi awal
data.plot(figsize=(10,4), title='Penjualan Pertalite')
plt.ylabel('Jumlah Penjualan')
plt.show()

# %%
# 6.Normalisasi
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)

# %%
# 7.Siapkan Data Sequence untuk LSTM
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

window_size = 6
X, y = create_sequences(data_scaled, window_size)

# Reshape untuk LSTM [samples, timesteps, features]
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# 8.Build & Train Model LSTM
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(window_size, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=100, verbose=0)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 9.Forecast 3 Bulan ke Depan
last_seq = data_scaled[-window_size:]
predictions = []

for _ in range(3):
    input_seq = last_seq.reshape((1, window_size, 1))
    pred = model.predict(input_seq, verbose=0)
    predictions.append(pred[0][0])
    last_seq = np.append(last_seq[1:], pred)

# Balikkan normalisasi
forecast = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))

# %%
# 10.Visualisasi Prediksi
forecast_dates = pd.date_range(start=data.index[-1] + pd.DateOffset(months=1), periods=3, freq='MS')
forecast_df = pd.DataFrame({'Forecast': forecast.flatten()}, index=forecast_dates)

# Gabungkan data terakhir dan prediksi
combined = pd.concat([data[-12:], forecast_df])

plt.figure(figsize=(10,5))
plt.plot(combined.index, combined['jumlah_penjualan'], label='Aktual')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Prediksi (3 Bulan)', linestyle='--', marker='o')
plt.title('Prediksi Penjualan Pertalite 3 Bulan ke Depan (LSTM)')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluasi Model LSTM

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Split data untuk uji: 3 bulan terakhir sebelum prediksi
X_train, y_train = X[:-3], y[:-3]
X_test, y_test = X[-3:], y[-3:]

# Prediksi untuk data uji
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_true = scaler.inverse_transform(y_test)

# Hitung error
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

print(f"📊 MAE: {mae:.2f}")
print(f"📊 RMSE: {rmse:.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 📊 MAE: 12830955.67
# 📊 RMSE: 15309579.12

# %%
plt.figure(figsize=(10,5))
plt.plot(y_true, label='Aktual', marker='o')
plt.plot(y_pred, label='Prediksi', marker='o')
plt.title('Prediksi vs Aktual (3 Bulan Terakhir)')
plt.legend()
plt.grid(True)
plt.show()

# %%
history = model.fit(X, y, epochs=100, validation_split=0.2)

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Train vs Validation Loss')
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.0111 - val_loss: 0.1593
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - loss: 0.0105 - val_loss: 0.1623
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0099 - val_loss: 0.1666
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0094 - val_loss: 0.1718
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0091 - val_loss: 0.1772
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0088 - val_loss: 0.1822
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0086 - val_loss: 0.1864
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 0.0084 - val_loss: 0.1896
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0082 - val_loss: 0.1921
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0082 - val_loss: 0.1947
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0081 - val_loss: 0.1978
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0080 - val_loss: 0.2016
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - loss: 0.0078 - val_loss: 0.2058
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0076 - val_loss: 0.2102
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0074 - val_loss: 0.2146
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0072 - val_loss: 0.2186
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0071 - val_loss: 0.2219
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - loss: 0.0070 - val_loss: 0.2248
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - loss: 0.0069 - val_loss: 0.2277
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0068 - val_loss: 0.2309
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.0067 - val_loss: 0.2346
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.0066 - val_loss: 0.2390
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0066 - val_loss: 0.2439
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0065 - val_loss: 0.2492
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0064 - val_loss: 0.2543
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0064 - val_loss: 0.2589
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0063 - val_loss: 0.2627
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0063 - val_loss: 0.2657
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0062 - val_loss: 0.2681
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0062 - val_loss: 0.2703
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0061 - val_loss: 0.2727
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0061 - val_loss: 0.2755
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0060 - val_loss: 0.2789
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0060 - val_loss: 0.2823
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0060 - val_loss: 0.2854
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0059 - val_loss: 0.2878
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.0059 - val_loss: 0.2892
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0059 - val_loss: 0.2899
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0059 - val_loss: 0.2903
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0058 - val_loss: 0.2905
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0058 - val_loss: 0.2909
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0058 - val_loss: 0.2916
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0058 - val_loss: 0.2923
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0057 - val_loss: 0.2929
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0057 - val_loss: 0.2932
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0057 - val_loss: 0.2931
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0057 - val_loss: 0.2928
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0057 - val_loss: 0.2924
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0057 - val_loss: 0.2920
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0056 - val_loss: 0.2918
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0056 - val_loss: 0.2918
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0056 - val_loss: 0.2921
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0056 - val_loss: 0.2925
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0056 - val_loss: 0.2927
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0056 - val_loss: 0.2928
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0056 - val_loss: 0.2926
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0056 - val_loss: 0.2924
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0055 - val_loss: 0.2921
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0055 - val_loss: 0.2920
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0055 - val_loss: 0.2921
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0055 - val_loss: 0.2923
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0055 - val_loss: 0.2925
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0055 - val_loss: 0.2926
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0055 - val_loss: 0.2927
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0055 - val_loss: 0.2929
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0055 - val_loss: 0.2934
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0055 - val_loss: 0.2943
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0054 - val_loss: 0.2953
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0054 - val_loss: 0.2961
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0054 - val_loss: 0.2967
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0054 - val_loss: 0.2970
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.0054 - val_loss: 0.2970
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0054 - val_loss: 0.2971
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0054 - val_loss: 0.2975
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0054 - val_loss: 0.2980
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0054 - val_loss: 0.2985
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0054 - val_loss: 0.2990
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0054 - val_loss: 0.2993
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0053 - val_loss: 0.2994
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0053 - val_loss: 0.2995
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0053 - val_loss: 0.2995
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0053 - val_loss: 0.2998
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0053 - val_loss: 0.3004
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0053 - val_loss: 0.3011
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0053 - val_loss: 0.3019
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - loss: 0.0053 - val_loss: 0.3024
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0053 - val_loss: 0.3025
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0053 - val_loss: 0.3024
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0053 - val_loss: 0.3022
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0053 - val_loss: 0.3022
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0052 - val_loss: 0.3024
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0052 - val_loss: 0.3027
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0052 - val_loss: 0.3031
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 0.0052 - val_loss: 0.3032
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0052 - val_loss: 0.3031
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0052 - val_loss: 0.3032
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0052 - val_loss: 0.3035
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0052 - val_loss: 0.3041
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0052 - val_loss: 0.3046
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0052 - val_loss: 0.3051

# %%
# Simpan model dengan format baru
model.save('model_lstm_pertalite.keras')
